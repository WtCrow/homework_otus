# %% [markdown]
# ## Задание: придумать метод для генерации коррелированного набора данных

# %%
from numpy.random import rand
from random import uniform
from matplotlib import pyplot
import numpy as np
from scipy import stats

mu, sigma = 0, 1
X = np.random.normal(mu, sigma, 1000)

r = -.6
mix_x, man_x = min(X), max(X)
Y = [x * r + uniform(mix_x, man_x) * (1 - abs(r)) for x in X]

pyplot.scatter(X, Y)
pyplot.show()

coef, p = stats.spearmanr(X, Y)
print(coef)
# Out:
# -0.6064751104751105

# %% [markdown]
# #
