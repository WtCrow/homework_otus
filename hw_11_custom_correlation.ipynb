# %%
from numpy.random import rand
from random import uniform
from matplotlib import pyplot
import numpy as np

mu, sigma = .5, .1
X = np.random.normal(mu, sigma, 1000)

r = -.6

mix_x, man_x = min(X), max(X)

Y = []
for x in X:
    Y.append(x * r + uniform(mix_x, man_x) * (1 - abs(r)))

pyplot.scatter(X, Y)
pyplot.show()

coef, p = spearmanr(X, Y)
print(coef)
# Out:
# -0.61595331995332

# %% [markdown]
# #
